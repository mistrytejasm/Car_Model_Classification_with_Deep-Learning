# %%
# !pip install duckduckgo_search

# %% [markdown]
# # V1. old Script

# %%
import os
import requests
from PIL import Image
from io import BytesIO
from duckduckgo_search import DDGS

# Function to Search Images
def search_images(query, max_images=100):
    urls = []
    with DDGS() as ddgs:
        results = ddgs.images(keywords=query, max_results=max_images)
        for result in results:
            url = result.get("image")
            if url:
                urls.append(url)
    print(f"Found {len(urls)} image URLs for '{query}'")
    return urls

# Car Models You Want
car_models = [
    "Maruti Suzuki Swift", "Maruti Suzuki Baleno", "Mahindra Thar", 
    "Tata Nexon", "Hyundai Creta", "Hyundai i20", "Kia Seltos", 
    "Toyota Fortuner", "Honda City", "BMW X5"
]

# Base Directory to Save
base_dir = "car_dataset/train"
os.makedirs(base_dir, exist_ok=True)

# Function to Download Images
def download_car_images(model_name, max_images=100):
    folder = os.path.join(base_dir, model_name.lower().replace(" ", "_"))
    os.makedirs(folder, exist_ok=True)
    
    urls = search_images(model_name, max_images)
    
    for i, url in enumerate(urls):
        try:
            response = requests.get(url, timeout=10)
            img = Image.open(BytesIO(response.content)).convert("RGB")
            # img = img.resize((256, 256))
            fname = f"{model_name.lower().replace(' ', '_')}_{i}.jpg"
            img.save(os.path.join(folder, fname))
            print(f"Saved image {i+1} for {model_name}")
        except Exception as e:
            print(f"Failed to download image {i+1}: {e}")

# Download Images for All Car Models
for model in car_models:
    print("\n=== Scraping images for:", model)
    download_car_images(model, max_images=100)

# %% [markdown]
# # V2.

# %%
import os
import requests
import json
from PIL import Image
from io import BytesIO
from duckduckgo_search import DDGS

# Load Custom Queries
with open("car_model_queries.json", "r") as f:
    model_queries = json.load(f)

# Image Search
def search_images(query, max_images=100):
    urls = []
    with DDGS() as ddgs:
        results = ddgs.images(keywords=query, max_results=max_images)
        for result in results:
            url = result.get("image")
            if url:
                urls.append(url)
    return urls

# Save Directory
base_dir = "car_dataset/train"
os.makedirs(base_dir, exist_ok=True)

# Download Function
def download_car_images(model_name, queries, total_images=200):
    folder = os.path.join(base_dir, model_name.lower().replace(" ", "_"))
    os.makedirs(folder, exist_ok=True)

    downloaded = 0
    per_query = max(total_images // len(queries), 1)

    for query in queries:
        urls = search_images(query, max_images=per_query)
        for i, url in enumerate(urls):
            if downloaded >= total_images:
                break
            try:
                response = requests.get(url, timeout=10)
                img = Image.open(BytesIO(response.content)).convert("RGB")
                fname = f"{model_name.lower().replace(' ', '_')}_{downloaded}.jpg"
                img.save(os.path.join(folder, fname))
                downloaded += 1
                print(f"Saved image {downloaded} for {model_name}")
            except Exception as e:
                print(f"Failed to download from {url}: {e}")

# Download for All Models
for model, queries in model_queries.items():
    print(f"\n=== Downloading for: {model}")
    download_car_images(model, queries, total_images=100)

# %% [markdown]
# # V3. final working version

# %%
import os
import requests
import json
import time
from PIL import Image
from io import BytesIO
from ddgs import DDGS

#  Load Custom Queries 
with open("car_model_queries.json", "r") as f:
    model_queries = json.load(f)

#  Image Search 
def search_images(query, max_images=100, delay=1.0):
    urls = []
    try:
        with DDGS() as ddgs:
            results = ddgs.images(query, max_results=max_images)
            for result in results:
                url = result.get("image")
                if url:
                    urls.append(url)
                time.sleep(delay)  # avoid triggering rate limit
    except Exception as e:
        print(f"[ERROR] Image search failed for query '{query}': {e}")
    return urls

#  Save Directory 
base_dir = "car_dataset/train"
os.makedirs(base_dir, exist_ok=True)

#  Download Function 
def download_car_images(model_name, queries, total_images=300, per_query_limit=100):
    folder = os.path.join(base_dir, model_name.lower().replace(" ", "_"))
    os.makedirs(folder, exist_ok=True)

    # Count already downloaded images
    downloaded = len([f for f in os.listdir(folder) if f.endswith(".jpg")])

    if downloaded >= total_images:
        print(f"⏩ Skipping {model_name} — already has {downloaded} images.")
        return

    per_query = max((total_images - downloaded) // len(queries), 1)

    for query in queries:
        print(f"🔎 Searching for: {query}")
        urls = search_images(query, max_images=min(per_query, per_query_limit))
        print(f"  → Found {len(urls)} image URLs.")

        for url in urls:
            if downloaded >= total_images:
                break
            try:
                response = requests.get(url, timeout=10)
                img = Image.open(BytesIO(response.content)).convert("RGB")

                fname = f"{model_name.lower().replace(' ', '_')}_{downloaded:03d}.jpg"
                img.save(os.path.join(folder, fname))
                downloaded += 1
                print(f"  ✔ Saved image {downloaded} for {model_name}")
            except Exception as e:
                print(f"  ✖ Failed to download image: {e}")
            time.sleep(0.2)

    print(f"✅ Finished downloading for {model_name}: {downloaded} images.\n")


#  Download All Models 
for model, queries in model_queries.items():
    print(f"\n📥 Downloading images for: {model}")
    download_car_images(model, queries, total_images=300)

print("🎉 All downloads completed!")
# Out:
# 📥 Downloading images for: Tata Motors Harrier
# 🔎 Searching for: Tata Motors Harrier front view
#   → Found 60 image URLs.
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26DD50>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26E700>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE642020>
#   ✔ Saved image 1 for Tata Motors Harrier
#   ✔ Saved image 2 for Tata Motors Harrier
#   ✔ Saved image 3 for Tata Motors Harrier
#   ✔ Saved image 4 for Tata Motors Harrier
#   ✔ Saved image 5 for Tata Motors Harrier
#   ✔ Saved image 6 for Tata Motors Harrier
#   ✔ Saved image 7 for Tata Motors Harrier
#   ✔ Saved image 8 for Tata Motors Harrier
#   ✔ Saved image 9 for Tata Motors Harrier
#   ✔ Saved image 10 for Tata Motors Harrier
#   ✔ Saved image 11 for Tata Motors Harrier
#   ✔ Saved image 12 for Tata Motors Harrier
#   ✔ Saved image 13 for Tata Motors Harrier
#   ✔ Saved image 14 for Tata Motors Harrier
#   ✔ Saved image 15 for Tata Motors Harrier
#   ✔ Saved image 16 for Tata Motors Harrier
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 17 for Tata Motors Harrier
#   ✔ Saved image 18 for Tata Motors Harrier
#   ✔ Saved image 19 for Tata Motors Harrier
#   ✔ Saved image 20 for Tata Motors Harrier
#   ✔ Saved image 21 for Tata Motors Harrier
#   ✔ Saved image 22 for Tata Motors Harrier
#   ✔ Saved image 23 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643600>
#   ✔ Saved image 24 for Tata Motors Harrier
#   ✔ Saved image 25 for Tata Motors Harrier
#   ✔ Saved image 26 for Tata Motors Harrier
#   ✔ Saved image 27 for Tata Motors Harrier
#   ✔ Saved image 28 for Tata Motors Harrier
#   ✔ Saved image 29 for Tata Motors Harrier
#   ✔ Saved image 30 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE642070>
#   ✔ Saved image 31 for Tata Motors Harrier
#   ✔ Saved image 32 for Tata Motors Harrier
#   ✔ Saved image 33 for Tata Motors Harrier
#   ✔ Saved image 34 for Tata Motors Harrier
#   ✔ Saved image 35 for Tata Motors Harrier
#   ✔ Saved image 36 for Tata Motors Harrier
#   ✔ Saved image 37 for Tata Motors Harrier
#   ✔ Saved image 38 for Tata Motors Harrier
#   ✔ Saved image 39 for Tata Motors Harrier
#   ✔ Saved image 40 for Tata Motors Harrier
#   ✔ Saved image 41 for Tata Motors Harrier
# d:\AIML And DSA\AI Projects\FastAPI\.venv\lib\site-packages\PIL\Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   ✔ Saved image 42 for Tata Motors Harrier
#   ✔ Saved image 43 for Tata Motors Harrier
#   ✔ Saved image 44 for Tata Motors Harrier
#   ✔ Saved image 45 for Tata Motors Harrier
#   ✔ Saved image 46 for Tata Motors Harrier
#   ✔ Saved image 47 for Tata Motors Harrier
#   ✔ Saved image 48 for Tata Motors Harrier
#   ✔ Saved image 49 for Tata Motors Harrier
#   ✔ Saved image 50 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643600>
#   ✔ Saved image 51 for Tata Motors Harrier
#   ✔ Saved image 52 for Tata Motors Harrier
#   ✔ Saved image 53 for Tata Motors Harrier
# 🔎 Searching for: Tata Motors Harrier side view
#   → Found 60 image URLs.
#   ✔ Saved image 54 for Tata Motors Harrier
#   ✔ Saved image 55 for Tata Motors Harrier
#   ✔ Saved image 56 for Tata Motors Harrier
#   ✔ Saved image 57 for Tata Motors Harrier
#   ✔ Saved image 58 for Tata Motors Harrier
#   ✔ Saved image 59 for Tata Motors Harrier
#   ✔ Saved image 60 for Tata Motors Harrier
#   ✔ Saved image 61 for Tata Motors Harrier
#   ✔ Saved image 62 for Tata Motors Harrier
#   ✔ Saved image 63 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE640B80>
#   ✔ Saved image 64 for Tata Motors Harrier
#   ✔ Saved image 65 for Tata Motors Harrier
#   ✔ Saved image 66 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9710>
#   ✔ Saved image 67 for Tata Motors Harrier
#   ✔ Saved image 68 for Tata Motors Harrier
#   ✔ Saved image 69 for Tata Motors Harrier
#   ✔ Saved image 70 for Tata Motors Harrier
#   ✔ Saved image 71 for Tata Motors Harrier
#   ✔ Saved image 72 for Tata Motors Harrier
#   ✔ Saved image 73 for Tata Motors Harrier
#   ✔ Saved image 74 for Tata Motors Harrier
#   ✔ Saved image 75 for Tata Motors Harrier
#   ✔ Saved image 76 for Tata Motors Harrier
#   ✔ Saved image 77 for Tata Motors Harrier
#   ✔ Saved image 78 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE6435B0>
#   ✔ Saved image 79 for Tata Motors Harrier
#   ✔ Saved image 80 for Tata Motors Harrier
#   ✔ Saved image 81 for Tata Motors Harrier
#   ✔ Saved image 82 for Tata Motors Harrier
#   ✔ Saved image 83 for Tata Motors Harrier
#   ✔ Saved image 84 for Tata Motors Harrier
#   ✔ Saved image 85 for Tata Motors Harrier
#   ✔ Saved image 86 for Tata Motors Harrier
#   ✔ Saved image 87 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9710>
#   ✔ Saved image 88 for Tata Motors Harrier
#   ✔ Saved image 89 for Tata Motors Harrier
#   ✔ Saved image 90 for Tata Motors Harrier
#   ✔ Saved image 91 for Tata Motors Harrier
#   ✔ Saved image 92 for Tata Motors Harrier
#   ✔ Saved image 93 for Tata Motors Harrier
#   ✔ Saved image 94 for Tata Motors Harrier
#   ✔ Saved image 95 for Tata Motors Harrier
#   ✔ Saved image 96 for Tata Motors Harrier
#   ✔ Saved image 97 for Tata Motors Harrier
#   ✔ Saved image 98 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26F9C0>
#   ✔ Saved image 99 for Tata Motors Harrier
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 100 for Tata Motors Harrier
#   ✔ Saved image 101 for Tata Motors Harrier
#   ✔ Saved image 102 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CB843DD0>
#   ✔ Saved image 103 for Tata Motors Harrier
#   ✔ Saved image 104 for Tata Motors Harrier
#   ✔ Saved image 105 for Tata Motors Harrier
#   ✔ Saved image 106 for Tata Motors Harrier
# 🔎 Searching for: Tata Motors Harrier rear view
#   → Found 60 image URLs.
#   ✔ Saved image 107 for Tata Motors Harrier
#   ✔ Saved image 108 for Tata Motors Harrier
#   ✔ Saved image 109 for Tata Motors Harrier
#   ✔ Saved image 110 for Tata Motors Harrier
#   ✔ Saved image 111 for Tata Motors Harrier
#   ✔ Saved image 112 for Tata Motors Harrier
#   ✔ Saved image 113 for Tata Motors Harrier
#   ✔ Saved image 114 for Tata Motors Harrier
#   ✔ Saved image 115 for Tata Motors Harrier
#   ✔ Saved image 116 for Tata Motors Harrier
#   ✔ Saved image 117 for Tata Motors Harrier
#   ✔ Saved image 118 for Tata Motors Harrier
#   ✔ Saved image 119 for Tata Motors Harrier
#   ✔ Saved image 120 for Tata Motors Harrier
#   ✔ Saved image 121 for Tata Motors Harrier
#   ✔ Saved image 122 for Tata Motors Harrier
#   ✔ Saved image 123 for Tata Motors Harrier
#   ✔ Saved image 124 for Tata Motors Harrier
#   ✔ Saved image 125 for Tata Motors Harrier
#   ✔ Saved image 126 for Tata Motors Harrier
#   ✔ Saved image 127 for Tata Motors Harrier
#   ✔ Saved image 128 for Tata Motors Harrier
#   ✔ Saved image 129 for Tata Motors Harrier
#   ✔ Saved image 130 for Tata Motors Harrier
#   ✔ Saved image 131 for Tata Motors Harrier
#   ✔ Saved image 132 for Tata Motors Harrier
#   ✔ Saved image 133 for Tata Motors Harrier
#   ✔ Saved image 134 for Tata Motors Harrier
#   ✔ Saved image 135 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CB843DD0>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9710>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CB843DD0>
#   ✔ Saved image 136 for Tata Motors Harrier
#   ✔ Saved image 137 for Tata Motors Harrier
#   ✔ Saved image 138 for Tata Motors Harrier
#   ✔ Saved image 139 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643600>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9710>
#   ✔ Saved image 140 for Tata Motors Harrier
#   ✔ Saved image 141 for Tata Motors Harrier
#   ✔ Saved image 142 for Tata Motors Harrier
#   ✔ Saved image 143 for Tata Motors Harrier
#   ✔ Saved image 144 for Tata Motors Harrier
#   ✔ Saved image 145 for Tata Motors Harrier
#   ✔ Saved image 146 for Tata Motors Harrier
#   ✔ Saved image 147 for Tata Motors Harrier
#   ✔ Saved image 148 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26FA60>
#   ✔ Saved image 149 for Tata Motors Harrier
#   ✔ Saved image 150 for Tata Motors Harrier
#   ✔ Saved image 151 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26F9C0>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9760>
#   ✔ Saved image 152 for Tata Motors Harrier
#   ✔ Saved image 153 for Tata Motors Harrier
#   ✔ Saved image 154 for Tata Motors Harrier
#   ✔ Saved image 155 for Tata Motors Harrier
#   ✔ Saved image 156 for Tata Motors Harrier
#   ✔ Saved image 157 for Tata Motors Harrier
#   ✔ Saved image 158 for Tata Motors Harrier
# 🔎 Searching for: Tata Motors Harrier on highway
#   → Found 60 image URLs.
#   ✔ Saved image 159 for Tata Motors Harrier
#   ✔ Saved image 160 for Tata Motors Harrier
#   ✔ Saved image 161 for Tata Motors Harrier
#   ✔ Saved image 162 for Tata Motors Harrier
#   ✔ Saved image 163 for Tata Motors Harrier
#   ✔ Saved image 164 for Tata Motors Harrier
#   ✔ Saved image 165 for Tata Motors Harrier
#   ✔ Saved image 166 for Tata Motors Harrier
#   ✔ Saved image 167 for Tata Motors Harrier
#   ✔ Saved image 168 for Tata Motors Harrier
#   ✔ Saved image 169 for Tata Motors Harrier
#   ✔ Saved image 170 for Tata Motors Harrier
#   ✔ Saved image 171 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE642070>
#   ✔ Saved image 172 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253C90>
#   ✔ Saved image 173 for Tata Motors Harrier
#   ✔ Saved image 174 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCE035B0>
#   ✔ Saved image 175 for Tata Motors Harrier
#   ✔ Saved image 176 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9760>
#   ✔ Saved image 177 for Tata Motors Harrier
#   ✔ Saved image 178 for Tata Motors Harrier
#   ✔ Saved image 179 for Tata Motors Harrier
#   ✔ Saved image 180 for Tata Motors Harrier
#   ✔ Saved image 181 for Tata Motors Harrier
#   ✔ Saved image 182 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26F9C0>
#   ✔ Saved image 183 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26F9C0>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26FA60>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CBA83380>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD32B740>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253C90>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE591A30>
#   ✔ Saved image 184 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9760>
#   ✔ Saved image 185 for Tata Motors Harrier
#   ✔ Saved image 186 for Tata Motors Harrier
#   ✔ Saved image 187 for Tata Motors Harrier
#   ✔ Saved image 188 for Tata Motors Harrier
#   ✔ Saved image 189 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA9760>
#   ✔ Saved image 190 for Tata Motors Harrier
#   ✔ Saved image 191 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253F10>
#   ✔ Saved image 192 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26E6B0>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE591A30>
#   ✔ Saved image 193 for Tata Motors Harrier
#   ✖ Failed to download image: HTTPSConnectionPool(host='pdf4pro.com', port=443): Max retries exceeded with url: /cache/preview/c/8/9/2/e/7/a/9/thumb-c892e7a90f2debf09db8ddbc18f07288.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000212CE7C2B90>, 'Connection to pdf4pro.com timed out. (connect timeout=10)'))
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26FA60>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE640B80>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643560>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE7D7060>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE591A30>
#   ✔ Saved image 194 for Tata Motors Harrier
#   ✔ Saved image 195 for Tata Motors Harrier
#   ✔ Saved image 196 for Tata Motors Harrier
# 🔎 Searching for: Tata Motors Harrier on road
#   → Found 60 image URLs.
#   ✔ Saved image 197 for Tata Motors Harrier
#   ✔ Saved image 198 for Tata Motors Harrier
#   ✔ Saved image 199 for Tata Motors Harrier
#   ✔ Saved image 200 for Tata Motors Harrier
#   ✔ Saved image 201 for Tata Motors Harrier
#   ✔ Saved image 202 for Tata Motors Harrier
#   ✔ Saved image 203 for Tata Motors Harrier
#   ✔ Saved image 204 for Tata Motors Harrier
#   ✔ Saved image 205 for Tata Motors Harrier
#   ✔ Saved image 206 for Tata Motors Harrier
#   ✔ Saved image 207 for Tata Motors Harrier
#   ✔ Saved image 208 for Tata Motors Harrier
#   ✔ Saved image 209 for Tata Motors Harrier
#   ✔ Saved image 210 for Tata Motors Harrier
#   ✔ Saved image 211 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCE035B0>
#   ✔ Saved image 212 for Tata Motors Harrier
#   ✔ Saved image 213 for Tata Motors Harrier
#   ✔ Saved image 214 for Tata Motors Harrier
#   ✔ Saved image 215 for Tata Motors Harrier
#   ✔ Saved image 216 for Tata Motors Harrier
#   ✖ Failed to download image: HTTPSConnectionPool(host='allindianewsmedia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2024/11/image-768x480.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997)')))
#   ✔ Saved image 217 for Tata Motors Harrier
#   ✔ Saved image 218 for Tata Motors Harrier
#   ✔ Saved image 219 for Tata Motors Harrier
#   ✔ Saved image 220 for Tata Motors Harrier
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 221 for Tata Motors Harrier
#   ✔ Saved image 222 for Tata Motors Harrier
#   ✔ Saved image 223 for Tata Motors Harrier
#   ✔ Saved image 224 for Tata Motors Harrier
#   ✔ Saved image 225 for Tata Motors Harrier
#   ✔ Saved image 226 for Tata Motors Harrier
#   ✔ Saved image 227 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26E6B0>
#   ✔ Saved image 228 for Tata Motors Harrier
#   ✔ Saved image 229 for Tata Motors Harrier
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 230 for Tata Motors Harrier
#   ✔ Saved image 231 for Tata Motors Harrier
#   ✔ Saved image 232 for Tata Motors Harrier
#   ✔ Saved image 233 for Tata Motors Harrier
#   ✔ Saved image 234 for Tata Motors Harrier
#   ✔ Saved image 235 for Tata Motors Harrier
#   ✔ Saved image 236 for Tata Motors Harrier
#   ✔ Saved image 237 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE591A30>
#   ✔ Saved image 238 for Tata Motors Harrier
#   ✔ Saved image 239 for Tata Motors Harrier
#   ✔ Saved image 240 for Tata Motors Harrier
#   ✔ Saved image 241 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643560>
#   ✔ Saved image 242 for Tata Motors Harrier
#   ✔ Saved image 243 for Tata Motors Harrier
#   ✔ Saved image 244 for Tata Motors Harrier
#   ✔ Saved image 245 for Tata Motors Harrier
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD26F9C0>
#   ✔ Saved image 246 for Tata Motors Harrier
#   ✔ Saved image 247 for Tata Motors Harrier
#   ✔ Saved image 248 for Tata Motors Harrier
# ✅ Finished downloading for Tata Motors Harrier: 248 images.
#
#
# 📥 Downloading images for: Mahindra XUV500
# 🔎 Searching for: Mahindra XUV500 front view
#   → Found 60 image URLs.
#   ✔ Saved image 1 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD32B740>
#   ✔ Saved image 2 for Mahindra XUV500
#   ✔ Saved image 3 for Mahindra XUV500
#   ✔ Saved image 4 for Mahindra XUV500
#   ✔ Saved image 5 for Mahindra XUV500
#   ✔ Saved image 6 for Mahindra XUV500
#   ✔ Saved image 7 for Mahindra XUV500
#   ✔ Saved image 8 for Mahindra XUV500
#   ✔ Saved image 9 for Mahindra XUV500
#   ✔ Saved image 10 for Mahindra XUV500
#   ✔ Saved image 11 for Mahindra XUV500
#   ✔ Saved image 12 for Mahindra XUV500
#   ✔ Saved image 13 for Mahindra XUV500
#   ✔ Saved image 14 for Mahindra XUV500
#   ✔ Saved image 15 for Mahindra XUV500
#   ✔ Saved image 16 for Mahindra XUV500
#   ✔ Saved image 17 for Mahindra XUV500
#   ✔ Saved image 18 for Mahindra XUV500
#   ✔ Saved image 19 for Mahindra XUV500
#   ✔ Saved image 20 for Mahindra XUV500
#   ✔ Saved image 21 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE7D6390>
#   ✔ Saved image 22 for Mahindra XUV500
#   ✔ Saved image 23 for Mahindra XUV500
#   ✔ Saved image 24 for Mahindra XUV500
#   ✔ Saved image 25 for Mahindra XUV500
#   ✔ Saved image 26 for Mahindra XUV500
#   ✔ Saved image 27 for Mahindra XUV500
#   ✔ Saved image 28 for Mahindra XUV500
#   ✔ Saved image 29 for Mahindra XUV500
#   ✔ Saved image 30 for Mahindra XUV500
#   ✔ Saved image 31 for Mahindra XUV500
#   ✔ Saved image 32 for Mahindra XUV500
#   ✔ Saved image 33 for Mahindra XUV500
#   ✔ Saved image 34 for Mahindra XUV500
#   ✔ Saved image 35 for Mahindra XUV500
#   ✔ Saved image 36 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE7D6390>
#   ✔ Saved image 37 for Mahindra XUV500
#   ✔ Saved image 38 for Mahindra XUV500
#   ✔ Saved image 39 for Mahindra XUV500
#   ✔ Saved image 40 for Mahindra XUV500
#   ✔ Saved image 41 for Mahindra XUV500
#   ✔ Saved image 42 for Mahindra XUV500
#   ✔ Saved image 43 for Mahindra XUV500
#   ✔ Saved image 44 for Mahindra XUV500
#   ✔ Saved image 45 for Mahindra XUV500
#   ✔ Saved image 46 for Mahindra XUV500
#   ✔ Saved image 47 for Mahindra XUV500
#   ✔ Saved image 48 for Mahindra XUV500
#   ✔ Saved image 49 for Mahindra XUV500
#   ✔ Saved image 50 for Mahindra XUV500
#   ✔ Saved image 51 for Mahindra XUV500
#   ✔ Saved image 52 for Mahindra XUV500
#   ✔ Saved image 53 for Mahindra XUV500
#   ✔ Saved image 54 for Mahindra XUV500
#   ✔ Saved image 55 for Mahindra XUV500
#   ✔ Saved image 56 for Mahindra XUV500
#   ✔ Saved image 57 for Mahindra XUV500
# 🔎 Searching for: Mahindra XUV500 side view
#   → Found 60 image URLs.
#   ✔ Saved image 58 for Mahindra XUV500
#   ✔ Saved image 59 for Mahindra XUV500
#   ✔ Saved image 60 for Mahindra XUV500
#   ✔ Saved image 61 for Mahindra XUV500
#   ✔ Saved image 62 for Mahindra XUV500
#   ✔ Saved image 63 for Mahindra XUV500
#   ✔ Saved image 64 for Mahindra XUV500
#   ✔ Saved image 65 for Mahindra XUV500
#   ✔ Saved image 66 for Mahindra XUV500
#   ✔ Saved image 67 for Mahindra XUV500
#   ✔ Saved image 68 for Mahindra XUV500
#   ✔ Saved image 69 for Mahindra XUV500
#   ✔ Saved image 70 for Mahindra XUV500
#   ✔ Saved image 71 for Mahindra XUV500
#   ✔ Saved image 72 for Mahindra XUV500
#   ✔ Saved image 73 for Mahindra XUV500
#   ✔ Saved image 74 for Mahindra XUV500
#   ✖ Failed to download image: HTTPSConnectionPool(host='cdn.drivek.it', port=443): Max retries exceeded with url: /configurator-icon/cars/es/400/MAHINDRA/XUV500/30737_SUV-5-DOORS/mahindra-xuv500-side-view.png (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:997)')))
#   ✔ Saved image 75 for Mahindra XUV500
#   ✔ Saved image 76 for Mahindra XUV500
#   ✔ Saved image 77 for Mahindra XUV500
#   ✔ Saved image 78 for Mahindra XUV500
#   ✔ Saved image 79 for Mahindra XUV500
#   ✔ Saved image 80 for Mahindra XUV500
#   ✔ Saved image 81 for Mahindra XUV500
#   ✔ Saved image 82 for Mahindra XUV500
#   ✔ Saved image 83 for Mahindra XUV500
#   ✔ Saved image 84 for Mahindra XUV500
#   ✔ Saved image 85 for Mahindra XUV500
#   ✔ Saved image 86 for Mahindra XUV500
#   ✔ Saved image 87 for Mahindra XUV500
#   ✔ Saved image 88 for Mahindra XUV500
#   ✔ Saved image 89 for Mahindra XUV500
#   ✔ Saved image 90 for Mahindra XUV500
#   ✔ Saved image 91 for Mahindra XUV500
#   ✔ Saved image 92 for Mahindra XUV500
#   ✔ Saved image 93 for Mahindra XUV500
#   ✔ Saved image 94 for Mahindra XUV500
#   ✔ Saved image 95 for Mahindra XUV500
#   ✔ Saved image 96 for Mahindra XUV500
#   ✔ Saved image 97 for Mahindra XUV500
#   ✔ Saved image 98 for Mahindra XUV500
#   ✔ Saved image 99 for Mahindra XUV500
#   ✔ Saved image 100 for Mahindra XUV500
#   ✔ Saved image 101 for Mahindra XUV500
#   ✔ Saved image 102 for Mahindra XUV500
#   ✔ Saved image 103 for Mahindra XUV500
#   ✔ Saved image 104 for Mahindra XUV500
#   ✔ Saved image 105 for Mahindra XUV500
#   ✔ Saved image 106 for Mahindra XUV500
#   ✔ Saved image 107 for Mahindra XUV500
#   ✔ Saved image 108 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE7D5E90>
#   ✔ Saved image 109 for Mahindra XUV500
#   ✔ Saved image 110 for Mahindra XUV500
#   ✔ Saved image 111 for Mahindra XUV500
#   ✔ Saved image 112 for Mahindra XUV500
#   ✔ Saved image 113 for Mahindra XUV500
#   ✔ Saved image 114 for Mahindra XUV500
#   ✔ Saved image 115 for Mahindra XUV500
# 🔎 Searching for: Mahindra XUV500 rear view
#   → Found 60 image URLs.
#   ✔ Saved image 116 for Mahindra XUV500
#   ✔ Saved image 117 for Mahindra XUV500
#   ✔ Saved image 118 for Mahindra XUV500
#   ✔ Saved image 119 for Mahindra XUV500
#   ✔ Saved image 120 for Mahindra XUV500
#   ✔ Saved image 121 for Mahindra XUV500
#   ✔ Saved image 122 for Mahindra XUV500
#   ✔ Saved image 123 for Mahindra XUV500
#   ✔ Saved image 124 for Mahindra XUV500
#   ✔ Saved image 125 for Mahindra XUV500
#   ✔ Saved image 126 for Mahindra XUV500
#   ✔ Saved image 127 for Mahindra XUV500
#   ✔ Saved image 128 for Mahindra XUV500
#   ✔ Saved image 129 for Mahindra XUV500
#   ✔ Saved image 130 for Mahindra XUV500
#   ✔ Saved image 131 for Mahindra XUV500
#   ✔ Saved image 132 for Mahindra XUV500
#   ✔ Saved image 133 for Mahindra XUV500
#   ✔ Saved image 134 for Mahindra XUV500
#   ✔ Saved image 135 for Mahindra XUV500
#   ✔ Saved image 136 for Mahindra XUV500
#   ✔ Saved image 137 for Mahindra XUV500
#   ✔ Saved image 138 for Mahindra XUV500
#   ✔ Saved image 139 for Mahindra XUV500
#   ✔ Saved image 140 for Mahindra XUV500
#   ✔ Saved image 141 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCDA93F0>
#   ✔ Saved image 142 for Mahindra XUV500
#   ✔ Saved image 143 for Mahindra XUV500
#   ✔ Saved image 144 for Mahindra XUV500
#   ✔ Saved image 145 for Mahindra XUV500
#   ✔ Saved image 146 for Mahindra XUV500
#   ✔ Saved image 147 for Mahindra XUV500
#   ✔ Saved image 148 for Mahindra XUV500
#   ✔ Saved image 149 for Mahindra XUV500
#   ✔ Saved image 150 for Mahindra XUV500
#   ✔ Saved image 151 for Mahindra XUV500
#   ✔ Saved image 152 for Mahindra XUV500
#   ✔ Saved image 153 for Mahindra XUV500
#   ✔ Saved image 154 for Mahindra XUV500
#   ✔ Saved image 155 for Mahindra XUV500
#   ✔ Saved image 156 for Mahindra XUV500
#   ✔ Saved image 157 for Mahindra XUV500
#   ✔ Saved image 158 for Mahindra XUV500
#   ✔ Saved image 159 for Mahindra XUV500
#   ✔ Saved image 160 for Mahindra XUV500
#   ✔ Saved image 161 for Mahindra XUV500
#   ✔ Saved image 162 for Mahindra XUV500
#   ✔ Saved image 163 for Mahindra XUV500
#   ✔ Saved image 164 for Mahindra XUV500
#   ✔ Saved image 165 for Mahindra XUV500
#   ✔ Saved image 166 for Mahindra XUV500
#   ✔ Saved image 167 for Mahindra XUV500
#   ✔ Saved image 168 for Mahindra XUV500
#   ✔ Saved image 169 for Mahindra XUV500
#   ✔ Saved image 170 for Mahindra XUV500
#   ✔ Saved image 171 for Mahindra XUV500
#   ✔ Saved image 172 for Mahindra XUV500
#   ✔ Saved image 173 for Mahindra XUV500
#   ✔ Saved image 174 for Mahindra XUV500
# 🔎 Searching for: Mahindra XUV500 on highway
#   → Found 60 image URLs.
#   ✔ Saved image 175 for Mahindra XUV500
#   ✔ Saved image 176 for Mahindra XUV500
#   ✔ Saved image 177 for Mahindra XUV500
#   ✔ Saved image 178 for Mahindra XUV500
#   ✔ Saved image 179 for Mahindra XUV500
#   ✔ Saved image 180 for Mahindra XUV500
#   ✔ Saved image 181 for Mahindra XUV500
#   ✔ Saved image 182 for Mahindra XUV500
#   ✔ Saved image 183 for Mahindra XUV500
#   ✔ Saved image 184 for Mahindra XUV500
#   ✔ Saved image 185 for Mahindra XUV500
#   ✔ Saved image 186 for Mahindra XUV500
#   ✔ Saved image 187 for Mahindra XUV500
#   ✔ Saved image 188 for Mahindra XUV500
#   ✔ Saved image 189 for Mahindra XUV500
#   ✔ Saved image 190 for Mahindra XUV500
#   ✔ Saved image 191 for Mahindra XUV500
#   ✔ Saved image 192 for Mahindra XUV500
#   ✖ Failed to download image: HTTPSConnectionPool(host='wallpapercave.com', port=443): Read timed out. (read timeout=10)
#   ✔ Saved image 193 for Mahindra XUV500
#   ✔ Saved image 194 for Mahindra XUV500
#   ✔ Saved image 195 for Mahindra XUV500
#   ✔ Saved image 196 for Mahindra XUV500
#   ✔ Saved image 197 for Mahindra XUV500
#   ✔ Saved image 198 for Mahindra XUV500
#   ✔ Saved image 199 for Mahindra XUV500
#   ✔ Saved image 200 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE642070>
#   ✔ Saved image 201 for Mahindra XUV500
#   ✔ Saved image 202 for Mahindra XUV500
#   ✔ Saved image 203 for Mahindra XUV500
#   ✔ Saved image 204 for Mahindra XUV500
#   ✔ Saved image 205 for Mahindra XUV500
#   ✔ Saved image 206 for Mahindra XUV500
#   ✔ Saved image 207 for Mahindra XUV500
#   ✔ Saved image 208 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCE006D0>
#   ✔ Saved image 209 for Mahindra XUV500
#   ✔ Saved image 210 for Mahindra XUV500
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE642070>
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253C90>
#   ✔ Saved image 211 for Mahindra XUV500
#   ✔ Saved image 212 for Mahindra XUV500
#   ✔ Saved image 213 for Mahindra XUV500
#   ✔ Saved image 214 for Mahindra XUV500
#   ✔ Saved image 215 for Mahindra XUV500
#   ✔ Saved image 216 for Mahindra XUV500
#   ✔ Saved image 217 for Mahindra XUV500
#   ✔ Saved image 218 for Mahindra XUV500
#   ✔ Saved image 219 for Mahindra XUV500
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 220 for Mahindra XUV500
#   ✔ Saved image 221 for Mahindra XUV500
#   ✔ Saved image 222 for Mahindra XUV500
#   ✔ Saved image 223 for Mahindra XUV500
#   ✔ Saved image 224 for Mahindra XUV500
#   ✔ Saved image 225 for Mahindra XUV500
#   ✔ Saved image 226 for Mahindra XUV500
#   ✔ Saved image 227 for Mahindra XUV500
#   ✔ Saved image 228 for Mahindra XUV500
# 🔎 Searching for: Mahindra XUV500 on road
#   → Found 60 image URLs.
#   ✔ Saved image 229 for Mahindra XUV500
#   ✔ Saved image 230 for Mahindra XUV500
#   ✔ Saved image 231 for Mahindra XUV500
#   ✔ Saved image 232 for Mahindra XUV500
#   ✔ Saved image 233 for Mahindra XUV500
#   ✔ Saved image 234 for Mahindra XUV500
#   ✔ Saved image 235 for Mahindra XUV500
#   ✔ Saved image 236 for Mahindra XUV500
#   ✔ Saved image 237 for Mahindra XUV500
#   ✔ Saved image 238 for Mahindra XUV500
#   ✔ Saved image 239 for Mahindra XUV500
#   ✔ Saved image 240 for Mahindra XUV500
#   ✔ Saved image 241 for Mahindra XUV500
#   ✔ Saved image 242 for Mahindra XUV500
#   ✔ Saved image 243 for Mahindra XUV500
#   ✔ Saved image 244 for Mahindra XUV500
#   ✔ Saved image 245 for Mahindra XUV500
#   ✔ Saved image 246 for Mahindra XUV500
#   ✔ Saved image 247 for Mahindra XUV500
#   ✔ Saved image 248 for Mahindra XUV500
#   ✔ Saved image 249 for Mahindra XUV500
#   ✔ Saved image 250 for Mahindra XUV500
#   ✔ Saved image 251 for Mahindra XUV500
#   ✔ Saved image 252 for Mahindra XUV500
#   ✔ Saved image 253 for Mahindra XUV500
#   ✔ Saved image 254 for Mahindra XUV500
#   ✔ Saved image 255 for Mahindra XUV500
#   ✔ Saved image 256 for Mahindra XUV500
#   ✔ Saved image 257 for Mahindra XUV500
#   ✔ Saved image 258 for Mahindra XUV500
#   ✔ Saved image 259 for Mahindra XUV500
#   ✔ Saved image 260 for Mahindra XUV500
#   ✔ Saved image 261 for Mahindra XUV500
#   ✔ Saved image 262 for Mahindra XUV500
#   ✔ Saved image 263 for Mahindra XUV500
#   ✔ Saved image 264 for Mahindra XUV500
#   ✔ Saved image 265 for Mahindra XUV500
#   ✔ Saved image 266 for Mahindra XUV500
#   ✔ Saved image 267 for Mahindra XUV500
#   ✔ Saved image 268 for Mahindra XUV500
#   ✔ Saved image 269 for Mahindra XUV500
#   ✔ Saved image 270 for Mahindra XUV500
#   ✔ Saved image 271 for Mahindra XUV500
#   ✔ Saved image 272 for Mahindra XUV500
#   ✔ Saved image 273 for Mahindra XUV500
#   ✔ Saved image 274 for Mahindra XUV500
#   ✔ Saved image 275 for Mahindra XUV500
#   ✔ Saved image 276 for Mahindra XUV500
#   ✔ Saved image 277 for Mahindra XUV500
#   ✔ Saved image 278 for Mahindra XUV500
#   ✔ Saved image 279 for Mahindra XUV500
#   ✔ Saved image 280 for Mahindra XUV500
#   ✔ Saved image 281 for Mahindra XUV500
#   ✔ Saved image 282 for Mahindra XUV500
#   ✔ Saved image 283 for Mahindra XUV500
#   ✔ Saved image 284 for Mahindra XUV500
#   ✔ Saved image 285 for Mahindra XUV500
#   ✔ Saved image 286 for Mahindra XUV500
#   ✔ Saved image 287 for Mahindra XUV500
#   ✔ Saved image 288 for Mahindra XUV500
# ✅ Finished downloading for Mahindra XUV500: 288 images.
#
#
# 📥 Downloading images for: Toyota Innova
# 🔎 Searching for: Toyota Innova front view
#   → Found 60 image URLs.
#   ✔ Saved image 1 for Toyota Innova
#   ✔ Saved image 2 for Toyota Innova
#   ✔ Saved image 3 for Toyota Innova
#   ✔ Saved image 4 for Toyota Innova
#   ✔ Saved image 5 for Toyota Innova
#   ✔ Saved image 6 for Toyota Innova
#   ✔ Saved image 7 for Toyota Innova
#   ✔ Saved image 8 for Toyota Innova
#   ✔ Saved image 9 for Toyota Innova
#   ✔ Saved image 10 for Toyota Innova
#   ✔ Saved image 11 for Toyota Innova
#   ✔ Saved image 12 for Toyota Innova
#   ✔ Saved image 13 for Toyota Innova
#   ✔ Saved image 14 for Toyota Innova
#   ✔ Saved image 15 for Toyota Innova
#   ✔ Saved image 16 for Toyota Innova
#   ✔ Saved image 17 for Toyota Innova
#   ✔ Saved image 18 for Toyota Innova
#   ✔ Saved image 19 for Toyota Innova
#   ✔ Saved image 20 for Toyota Innova
#   ✔ Saved image 21 for Toyota Innova
#   ✔ Saved image 22 for Toyota Innova
#   ✔ Saved image 23 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643560>
#   ✔ Saved image 24 for Toyota Innova
#   ✔ Saved image 25 for Toyota Innova
#   ✔ Saved image 26 for Toyota Innova
#   ✔ Saved image 27 for Toyota Innova
#   ✔ Saved image 28 for Toyota Innova
#   ✔ Saved image 29 for Toyota Innova
#   ✔ Saved image 30 for Toyota Innova
#   ✔ Saved image 31 for Toyota Innova
#   ✔ Saved image 32 for Toyota Innova
#   ✔ Saved image 33 for Toyota Innova
#   ✔ Saved image 34 for Toyota Innova
#   ✔ Saved image 35 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CBA83BA0>
#   ✔ Saved image 36 for Toyota Innova
#   ✔ Saved image 37 for Toyota Innova
#   ✔ Saved image 38 for Toyota Innova
#   ✔ Saved image 39 for Toyota Innova
#   ✔ Saved image 40 for Toyota Innova
#   ✔ Saved image 41 for Toyota Innova
#   ✔ Saved image 42 for Toyota Innova
#   ✔ Saved image 43 for Toyota Innova
#   ✔ Saved image 44 for Toyota Innova
#   ✔ Saved image 45 for Toyota Innova
#   ✔ Saved image 46 for Toyota Innova
#   ✔ Saved image 47 for Toyota Innova
#   ✔ Saved image 48 for Toyota Innova
#   ✔ Saved image 49 for Toyota Innova
#   ✔ Saved image 50 for Toyota Innova
#   ✔ Saved image 51 for Toyota Innova
#   ✔ Saved image 52 for Toyota Innova
#   ✔ Saved image 53 for Toyota Innova
#   ✔ Saved image 54 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CE643150>
#   ✔ Saved image 55 for Toyota Innova
#   ✔ Saved image 56 for Toyota Innova
#   ✔ Saved image 57 for Toyota Innova
# 🔎 Searching for: Toyota Innova side view
#   → Found 60 image URLs.
#   ✔ Saved image 58 for Toyota Innova
#   ✔ Saved image 59 for Toyota Innova
#   ✔ Saved image 60 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD32B740>
#   ✔ Saved image 61 for Toyota Innova
#   ✔ Saved image 62 for Toyota Innova
#   ✔ Saved image 63 for Toyota Innova
#   ✔ Saved image 64 for Toyota Innova
#   ✔ Saved image 65 for Toyota Innova
#   ✔ Saved image 66 for Toyota Innova
#   ✔ Saved image 67 for Toyota Innova
#   ✔ Saved image 68 for Toyota Innova
#   ✔ Saved image 69 for Toyota Innova
#   ✔ Saved image 70 for Toyota Innova
#   ✔ Saved image 71 for Toyota Innova
#   ✔ Saved image 72 for Toyota Innova
#   ✔ Saved image 73 for Toyota Innova
#   ✔ Saved image 74 for Toyota Innova
#   ✔ Saved image 75 for Toyota Innova
#   ✔ Saved image 76 for Toyota Innova
#   ✔ Saved image 77 for Toyota Innova
#   ✔ Saved image 78 for Toyota Innova
#   ✔ Saved image 79 for Toyota Innova
#   ✔ Saved image 80 for Toyota Innova
#   ✔ Saved image 81 for Toyota Innova
#   ✔ Saved image 82 for Toyota Innova
#   ✔ Saved image 83 for Toyota Innova
#   ✔ Saved image 84 for Toyota Innova
#   ✔ Saved image 85 for Toyota Innova
#   ✔ Saved image 86 for Toyota Innova
#   ✔ Saved image 87 for Toyota Innova
#   ✔ Saved image 88 for Toyota Innova
#   ✔ Saved image 89 for Toyota Innova
#   ✔ Saved image 90 for Toyota Innova
#   ✔ Saved image 91 for Toyota Innova
#   ✔ Saved image 92 for Toyota Innova
#   ✔ Saved image 93 for Toyota Innova
#   ✔ Saved image 94 for Toyota Innova
#   ✔ Saved image 95 for Toyota Innova
#   ✔ Saved image 96 for Toyota Innova
#   ✔ Saved image 97 for Toyota Innova
#   ✔ Saved image 98 for Toyota Innova
#   ✔ Saved image 99 for Toyota Innova
#   ✔ Saved image 100 for Toyota Innova
#   ✔ Saved image 101 for Toyota Innova
#   ✔ Saved image 102 for Toyota Innova
#   ✖ Failed to download image: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ Saved image 103 for Toyota Innova
#   ✔ Saved image 104 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD2FE930>
#   ✔ Saved image 105 for Toyota Innova
#   ✔ Saved image 106 for Toyota Innova
#   ✔ Saved image 107 for Toyota Innova
#   ✔ Saved image 108 for Toyota Innova
#   ✔ Saved image 109 for Toyota Innova
#   ✔ Saved image 110 for Toyota Innova
#   ✔ Saved image 111 for Toyota Innova
#   ✔ Saved image 112 for Toyota Innova
#   ✔ Saved image 113 for Toyota Innova
#   ✔ Saved image 114 for Toyota Innova
# 🔎 Searching for: Toyota Innova rear view
#   → Found 60 image URLs.
#   ✔ Saved image 115 for Toyota Innova
#   ✔ Saved image 116 for Toyota Innova
#   ✔ Saved image 117 for Toyota Innova
#   ✔ Saved image 118 for Toyota Innova
#   ✔ Saved image 119 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253C90>
#   ✔ Saved image 120 for Toyota Innova
#   ✔ Saved image 121 for Toyota Innova
#   ✔ Saved image 122 for Toyota Innova
#   ✔ Saved image 123 for Toyota Innova
#   ✔ Saved image 124 for Toyota Innova
#   ✔ Saved image 125 for Toyota Innova
#   ✔ Saved image 126 for Toyota Innova
#   ✔ Saved image 127 for Toyota Innova
#   ✔ Saved image 128 for Toyota Innova
#   ✔ Saved image 129 for Toyota Innova
#   ✔ Saved image 130 for Toyota Innova
#   ✔ Saved image 131 for Toyota Innova
#   ✔ Saved image 132 for Toyota Innova
#   ✔ Saved image 133 for Toyota Innova
#   ✔ Saved image 134 for Toyota Innova
#   ✔ Saved image 135 for Toyota Innova
#   ✔ Saved image 136 for Toyota Innova
#   ✔ Saved image 137 for Toyota Innova
#   ✔ Saved image 138 for Toyota Innova
#   ✔ Saved image 139 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD253C90>
#   ✔ Saved image 140 for Toyota Innova
#   ✔ Saved image 141 for Toyota Innova
#   ✔ Saved image 142 for Toyota Innova
#   ✔ Saved image 143 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CD252A70>
#   ✔ Saved image 144 for Toyota Innova
#   ✔ Saved image 145 for Toyota Innova
#   ✔ Saved image 146 for Toyota Innova
#   ✔ Saved image 147 for Toyota Innova
#   ✔ Saved image 148 for Toyota Innova
#   ✔ Saved image 149 for Toyota Innova
#   ✔ Saved image 150 for Toyota Innova
#   ✔ Saved image 151 for Toyota Innova
#   ✔ Saved image 152 for Toyota Innova
#   ✔ Saved image 153 for Toyota Innova
#   ✔ Saved image 154 for Toyota Innova
#   ✔ Saved image 155 for Toyota Innova
#   ✔ Saved image 156 for Toyota Innova
#   ✔ Saved image 157 for Toyota Innova
#   ✔ Saved image 158 for Toyota Innova
#   ✔ Saved image 159 for Toyota Innova
#   ✔ Saved image 160 for Toyota Innova
#   ✔ Saved image 161 for Toyota Innova
#   ✔ Saved image 162 for Toyota Innova
#   ✔ Saved image 163 for Toyota Innova
#   ✔ Saved image 164 for Toyota Innova
#   ✔ Saved image 165 for Toyota Innova
#   ✔ Saved image 166 for Toyota Innova
#   ✔ Saved image 167 for Toyota Innova
#   ✔ Saved image 168 for Toyota Innova
#   ✔ Saved image 169 for Toyota Innova
#   ✔ Saved image 170 for Toyota Innova
#   ✔ Saved image 171 for Toyota Innova
# 🔎 Searching for: Toyota Innova on highway
#   → Found 60 image URLs.
#   ✔ Saved image 172 for Toyota Innova
#   ✔ Saved image 173 for Toyota Innova
#   ✔ Saved image 174 for Toyota Innova
#   ✔ Saved image 175 for Toyota Innova
#   ✔ Saved image 176 for Toyota Innova
#   ✔ Saved image 177 for Toyota Innova
#   ✔ Saved image 178 for Toyota Innova
#   ✔ Saved image 179 for Toyota Innova
#   ✔ Saved image 180 for Toyota Innova
#   ✔ Saved image 181 for Toyota Innova
#   ✔ Saved image 182 for Toyota Innova
#   ✔ Saved image 183 for Toyota Innova
#   ✔ Saved image 184 for Toyota Innova
#   ✔ Saved image 185 for Toyota Innova
#   ✔ Saved image 186 for Toyota Innova
#   ✖ Failed to download image: HTTPSConnectionPool(host='thumbs.dreamstime.com', port=443): Read timed out. (read timeout=10)
#   ✔ Saved image 187 for Toyota Innova
#   ✔ Saved image 188 for Toyota Innova
#   ✔ Saved image 189 for Toyota Innova
#   ✔ Saved image 190 for Toyota Innova
#   ✔ Saved image 191 for Toyota Innova
#   ✔ Saved image 192 for Toyota Innova
#   ✔ Saved image 193 for Toyota Innova
#   ✔ Saved image 194 for Toyota Innova
#   ✔ Saved image 195 for Toyota Innova
#   ✔ Saved image 196 for Toyota Innova
#   ✔ Saved image 197 for Toyota Innova
#   ✔ Saved image 198 for Toyota Innova
#   ✔ Saved image 199 for Toyota Innova
#   ✔ Saved image 200 for Toyota Innova
#   ✔ Saved image 201 for Toyota Innova
#   ✔ Saved image 202 for Toyota Innova
#   ✔ Saved image 203 for Toyota Innova
#   ✔ Saved image 204 for Toyota Innova
#   ✔ Saved image 205 for Toyota Innova
#   ✔ Saved image 206 for Toyota Innova
#   ✔ Saved image 207 for Toyota Innova
#   ✔ Saved image 208 for Toyota Innova
#   ✔ Saved image 209 for Toyota Innova
#   ✔ Saved image 210 for Toyota Innova
#   ✔ Saved image 211 for Toyota Innova
#   ✔ Saved image 212 for Toyota Innova
#   ✔ Saved image 213 for Toyota Innova
#   ✔ Saved image 214 for Toyota Innova
#   ✔ Saved image 215 for Toyota Innova
#   ✔ Saved image 216 for Toyota Innova
#   ✔ Saved image 217 for Toyota Innova
#   ✔ Saved image 218 for Toyota Innova
#   ✔ Saved image 219 for Toyota Innova
#   ✔ Saved image 220 for Toyota Innova
#   ✔ Saved image 221 for Toyota Innova
#   ✔ Saved image 222 for Toyota Innova
#   ✔ Saved image 223 for Toyota Innova
#   ✔ Saved image 224 for Toyota Innova
#   ✔ Saved image 225 for Toyota Innova
#   ✔ Saved image 226 for Toyota Innova
#   ✔ Saved image 227 for Toyota Innova
#   ✔ Saved image 228 for Toyota Innova
#   ✔ Saved image 229 for Toyota Innova
#   ✔ Saved image 230 for Toyota Innova
# 🔎 Searching for: Toyota Innova on road
#   → Found 60 image URLs.
#   ✔ Saved image 231 for Toyota Innova
#   ✔ Saved image 232 for Toyota Innova
#   ✔ Saved image 233 for Toyota Innova
#   ✔ Saved image 234 for Toyota Innova
#   ✔ Saved image 235 for Toyota Innova
#   ✔ Saved image 236 for Toyota Innova
#   ✔ Saved image 237 for Toyota Innova
#   ✔ Saved image 238 for Toyota Innova
#   ✔ Saved image 239 for Toyota Innova
#   ✔ Saved image 240 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CB843DD0>
#   ✔ Saved image 241 for Toyota Innova
#   ✔ Saved image 242 for Toyota Innova
#   ✔ Saved image 243 for Toyota Innova
#   ✔ Saved image 244 for Toyota Innova
#   ✔ Saved image 245 for Toyota Innova
#   ✔ Saved image 246 for Toyota Innova
#   ✔ Saved image 247 for Toyota Innova
#   ✔ Saved image 248 for Toyota Innova
#   ✔ Saved image 249 for Toyota Innova
#   ✖ Failed to download image: cannot identify image file <_io.BytesIO object at 0x00000212CCE035B0>
#   ✔ Saved image 250 for Toyota Innova
#   ✔ Saved image 251 for Toyota Innova
#   ✔ Saved image 252 for Toyota Innova
#   ✔ Saved image 253 for Toyota Innova
#   ✔ Saved image 254 for Toyota Innova
#   ✔ Saved image 255 for Toyota Innova
#   ✔ Saved image 256 for Toyota Innova
#   ✔ Saved image 257 for Toyota Innova
#   ✔ Saved image 258 for Toyota Innova
#   ✔ Saved image 259 for Toyota Innova
#   ✔ Saved image 260 for Toyota Innova
#   ✔ Saved image 261 for Toyota Innova
#   ✔ Saved image 262 for Toyota Innova
#   ✔ Saved image 263 for Toyota Innova
#   ✔ Saved image 264 for Toyota Innova
#   ✔ Saved image 265 for Toyota Innova
#   ✔ Saved image 266 for Toyota Innova
#   ✔ Saved image 267 for Toyota Innova
#   ✔ Saved image 268 for Toyota Innova
#   ✔ Saved image 269 for Toyota Innova
#   ✔ Saved image 270 for Toyota Innova
#   ✔ Saved image 271 for Toyota Innova
#   ✔ Saved image 272 for Toyota Innova
#   ✔ Saved image 273 for Toyota Innova
#   ✔ Saved image 274 for Toyota Innova
#   ✔ Saved image 275 for Toyota Innova
#   ✔ Saved image 276 for Toyota Innova
#   ✔ Saved image 277 for Toyota Innova
#   ✔ Saved image 278 for Toyota Innova
#   ✔ Saved image 279 for Toyota Innova
#   ✔ Saved image 280 for Toyota Innova
#   ✔ Saved image 281 for Toyota Innova
#   ✔ Saved image 282 for Toyota Innova
#   ✔ Saved image 283 for Toyota Innova
#   ✔ Saved image 284 for Toyota Innova
#   ✔ Saved image 285 for Toyota Innova
#   ✔ Saved image 286 for Toyota Innova
#   ✔ Saved image 287 for Toyota Innova
#   ✔ Saved image 288 for Toyota Innova
# ✅ Finished downloading for Toyota Innova: 288 images.
#
# 🎉 All downloads completed!
